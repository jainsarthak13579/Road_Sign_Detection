# %% [markdown]
# ## Import required libraries

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import cv2
import tensorflow as tf
from PIL import Image
import os
os.chdir('D:/project/Traffic_Sign_Recognition')
from sklearn.model_selection import train_test_split
from keras.utils import to_categorical
from keras.models import Sequential, load_model
from keras.layers import Conv2D, MaxPool2D, Dense, Flatten, Dropout

# %% [markdown]
# ## Store data, labels in the list

# %%
data = []
labels = []
# We have 43 Classes
classes = 43
cur_path = os.getcwd()

# %%
cur_path
# Out:
# 'D:\\project\\Traffic_Sign_Recognition'

# %% [markdown]
# ## Preprocess the images

# %%
for i in range(classes):
    path = os.path.join(cur_path,'train',str(i))
    images = os.listdir(path)
    for a in images:
        try:
            image = Image.open(path + '\\'+ a)
            image = image.resize((30,30))
            image = np.array(image)
            data.append(image)
            labels.append(i)
        except Exception as e:
            print(e)

# %% [markdown]
# ## Converting lists into numpy arrays

# %%
data = np.array(data)
labels = np.array(labels)

# %% [markdown]
# ## Save Labels & Data for future use

# %%
# os.mkdir('training')

np.save('data.npy',data)
np.save('target.npy',labels)

# %% [markdown]
# ## Load data & Labels

# %%
data=np.load('data.npy')
labels=np.load('target.npy')

# %%
print(data.shape, labels.shape)
# Out:
# (39209, 30, 30, 3) (39209,)

# %%
X_train, X_test, y_train, y_test = train_test_split(data, labels, test_size=0.2, random_state=0)

# %%
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (31367, 30, 30, 3) (7842, 30, 30, 3) (31367,) (7842,)

# %% [markdown]
# ## Convert labels to onehot encoding

# %%
y_train = to_categorical(y_train, 43)
y_test = to_categorical(y_test, 43)

# %% [markdown]
# ## Now it's time to build the model

# %%
model = Sequential()
model.add(Conv2D(filters=32, kernel_size=(5,5), activation='relu', input_shape=X_train.shape[1:]))
model.add(Conv2D(filters=32, kernel_size=(5,5), activation='relu'))
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Dropout(rate=0.25))
model.add(Conv2D(filters=64, kernel_size=(3, 3), activation='relu'))
model.add(Conv2D(filters=64, kernel_size=(3, 3), activation='relu'))
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Dropout(rate=0.25))
model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(Dropout(rate=0.5))
# We have 43 classes that's why we have defined 43 in the dense
model.add(Dense(43, activation='softmax'))

# %%
#Compilation of the model
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
epochs = 20
history = model.fit(X_train, y_train, batch_size=32, epochs=epochs, validation_data=(X_test, y_test))
# Out:
# Epoch 1/20
# 981/981 [==============================] - 73s 74ms/step - loss: 0.2102 - accuracy: 0.9458 - val_loss: 0.0715 - val_accuracy: 0.9801
# Epoch 2/20
# 981/981 [==============================] - 84s 86ms/step - loss: 0.2148 - accuracy: 0.9434 - val_loss: 0.0695 - val_accuracy: 0.9799
# Epoch 3/20
# 981/981 [==============================] - 81s 82ms/step - loss: 0.2305 - accuracy: 0.9394 - val_loss: 0.0548 - val_accuracy: 0.9864
# Epoch 4/20
# 981/981 [==============================] - 96s 98ms/step - loss: 0.2239 - accuracy: 0.9433 - val_loss: 0.0705 - val_accuracy: 0.9795
# Epoch 5/20
# 981/981 [==============================] - 103s 105ms/step - loss: 0.2207 - accuracy: 0.9445 - val_loss: 0.1184 - val_accuracy: 0.9684
# Epoch 6/20
# 981/981 [==============================] - 108s 110ms/step - loss: 0.2202 - accuracy: 0.9447 - val_loss: 0.0583 - val_accuracy: 0.9860
# Epoch 7/20
# 981/981 [==============================] - 96s 98ms/step - loss: 0.2124 - accuracy: 0.9458 - val_loss: 0.0505 - val_accuracy: 0.9871
# Epoch 8/20
# 981/981 [==============================] - 100s 102ms/step - loss: 0.1906 - accuracy: 0.9504 - val_loss: 0.0764 - val_accuracy: 0.9806
# Epoch 9/20
# 981/981 [==============================] - 104s 106ms/step - loss: 0.2378 - accuracy: 0.9393 - val_loss: 0.0709 - val_accuracy: 0.9832
# Epoch 10/20
# 981/981 [==============================] - 93s 94ms/step - loss: 0.2224 - accuracy: 0.9446 - val_loss: 0.0781 - val_accuracy: 0.9792
# Epoch 11/20
# 981/981 [==============================] - 101s 103ms/step - loss: 0.1865 - accuracy: 0.9514 - val_loss: 0.0508 - val_accuracy: 0.9852
# Epoch 12/20
# 981/981 [==============================] - 99s 101ms/step - loss: 0.2360 - accuracy: 0.9404 - val_loss: 0.0941 - val_accuracy: 0.9783
# Epoch 13/20
# 981/981 [==============================] - 104s 106ms/step - loss: 0.2141 - accuracy: 0.9467 - val_loss: 0.0569 - val_accuracy: 0.9853
# Epoch 14/20
# 981/981 [==============================] - 104s 106ms/step - loss: 0.2158 - accuracy: 0.9456 - val_loss: 0.0835 - val_accuracy: 0.9790
# Epoch 15/20
# 981/981 [==============================] - 103s 105ms/step - loss: 0.2322 - accuracy: 0.9428 - val_loss: 0.0730 - val_accuracy: 0.9797
# Epoch 16/20
# 981/981 [==============================] - 94s 96ms/step - loss: 0.2236 - accuracy: 0.9471 - val_loss: 0.0674 - val_accuracy: 0.9828
# Epoch 17/20
# 981/981 [==============================] - 105s 107ms/step - loss: 0.2167 - accuracy: 0.9472 - val_loss: 0.1088 - val_accuracy: 0.9728
# Epoch 18/20
# 981/981 [==============================] - 104s 106ms/step - loss: 0.2308 - accuracy: 0.9439 - val_loss: 0.1068 - val_accuracy: 0.9705
# Epoch 19/20
# 981/981 [==============================] - 98s 100ms/step - loss: 0.2285 - accuracy: 0.9459 - val_loss: 0.0592 - val_accuracy: 0.9842
# Epoch 20/20
# 981/981 [==============================] - 104s 106ms/step - loss: 0.1933 - accuracy: 0.9526 - val_loss: 0.0658 - val_accuracy: 0.9827

# %%
# accuracy 
plt.figure(0)
plt.plot(history.history['accuracy'], label='training accuracy')
plt.plot(history.history['val_accuracy'], label='val accuracy')
plt.title('Accuracy')
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.legend()
plt.show()

# %%
# Loss
plt.plot(history.history['loss'], label='training loss')
plt.plot(history.history['val_loss'], label='val loss')
plt.title('Loss')
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend()
plt.show()

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 26, 26, 32)        2432
#
#  conv2d_1 (Conv2D)           (None, 22, 22, 32)        25632
#
#  max_pooling2d (MaxPooling2D  (None, 11, 11, 32)       0
#  )
#
#  dropout (Dropout)           (None, 11, 11, 32)        0
#
#  conv2d_2 (Conv2D)           (None, 9, 9, 64)          18496
#
#  conv2d_3 (Conv2D)           (None, 7, 7, 64)          36928
#
#  max_pooling2d_1 (MaxPooling  (None, 3, 3, 64)         0
#  2D)
#
#  dropout_1 (Dropout)         (None, 3, 3, 64)          0
#
#  flatten (Flatten)           (None, 576)               0
#
#  dense (Dense)               (None, 256)               147712
#
#  dropout_2 (Dropout)         (None, 256)               0
#
#  dense_1 (Dense)             (None, 43)                11051
#
# =================================================================
# Total params: 242,251
# Trainable params: 242,251
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## LEt's do testing on Test data

# %%
def testing(testcsv):
    y_test = pd.read_csv(testcsv)
    label = y_test["ClassId"].values
    imgs = y_test["Path"].values
    data=[]
    for img in imgs:
        image = Image.open(img)
        image = image.resize((30,30))
        data.append(np.array(image))
    X_test=np.array(data)
    return X_test,label

# %%
X_test, label = testing('Test.csv')

# %%
#Y_pred = model.predict_classes(X_test)
Y_pred =model.predict(X_test) 
Y_pred=np.argmax(Y_pred,axis=1)
Y_pred
# Out:
# 395/395 [==============================] - 6s 14ms/step
# array([16,  1, 38, ..., 32,  7, 10], dtype=int64)

# %% [markdown]
# ## Accuracy with the test data

# %%
from sklearn.metrics import accuracy_score
print(accuracy_score(label, Y_pred))
# Out:
# 0.9493269992082344

# %% [markdown]
# ## Save the model

# %%
model.save("TSR.h5")

# %% [markdown]
# ## Load the Model

# %%
import os
os.chdir(r'D:/project/Traffic_Sign_Recognition')
from keras.models import load_model
model = load_model('TSR.h5')

# %%
# Classes of trafic signs
classes = { 0:'Speed limit (20km/h)',
            1:'Speed limit (30km/h)', 
            2:'Speed limit (50km/h)', 
            3:'Speed limit (60km/h)', 
            4:'Speed limit (70km/h)', 
            5:'Speed limit (80km/h)', 
            6:'End of speed limit (80km/h)', 
            7:'Speed limit (100km/h)', 
            8:'Speed limit (120km/h)', 
            9:'No passing', 
            10:'No passing veh over 3.5 tons', 
            11:'Right-of-way at intersection', 
            12:'Priority road', 
            13:'Yield', 
            14:'Stop', 
            15:'No vehicles', 
            16:'Veh > 3.5 tons prohibited', 
            17:'No entry', 
            18:'General caution', 
            19:'Dangerous curve left', 
            20:'Dangerous curve right', 
            21:'Double curve', 
            22:'Bumpy road', 
            23:'Slippery road', 
            24:'Road narrows on the right', 
            25:'Road work', 
            26:'Traffic signals', 
            27:'Pedestrians', 
            28:'Children crossing', 
            29:'Bicycles crossing', 
            30:'Beware of ice/snow',
            31:'Wild animals crossing', 
            32:'End speed + passing limits', 
            33:'Turn right ahead', 
            34:'Turn left ahead', 
            35:'Ahead only', 
            36:'Go straight or right', 
            37:'Go straight or left', 
            38:'Keep right', 
            39:'Keep left', 
            40:'Roundabout mandatory', 
            41:'End of no passing', 
            42:'End no passing veh > 3.5 tons' }

# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
def test_on_img(img):
    data=[]
    image = Image.open(img)
    image = image.resize((30,30))
    data.append(np.array(image))
    X_test=np.array(data)
    Y_pred =model.predict(X_test)
    Y_pred=np.argmax(Y_pred,axis=1)
    return image,Y_pred

# %%
plot,prediction = test_on_img(r'D:/project/Traffic_Sign_Recognition/Test/00001.png')
s = [str(i) for i in prediction] 
a = int("".join(s)) 
print("Predicted traffic sign is: ", classes[a])
plt.imshow(plot)
plt.show()
# Out:
# 1/1 [==============================] - 0s 30ms/step
# Predicted traffic sign is:  Speed limit (30km/h)
